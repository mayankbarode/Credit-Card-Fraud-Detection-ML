# %% [markdown]
# #     CREDIT CARD FRAUD DETECTION

# %% [markdown]
# ## Importing Necessary packages

# %%
import math
import joblib
import sklearn 
import pickle
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


from sklearn.svm import SVC 
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report,accuracy_score,confusion_matrix

# %matplotlib inline

# %% [markdown]
# ## Importing the dataset

# %%
credit_card = pd.read_csv('creditcard.csv',sep=',')
credit_card.head(10)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
# 5   2.0 -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728  0.476201
# 6   4.0  1.229658  0.141004  0.045371  1.202613  0.191881  0.272708 -0.005159
# 7   7.0 -0.644269  1.417964  1.074380 -0.492199  0.948934  0.428118  1.120631
# 8   7.0 -0.894286  0.286157 -0.113192 -0.271526  2.669599  3.721818  0.370145
# 9   9.0 -0.338262  1.119593  1.044367 -0.222187  0.499361 -0.246761  0.651583
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
# 5  0.260314 -0.568671  ... -0.208254 -0.559825 -0.026398 -0.371427 -0.232794
# 6  0.081213  0.464960  ... -0.167716 -0.270710 -0.154104 -0.780055  0.750137
# 7 -3.807864  0.615375  ...  1.943465 -1.015455  0.057504 -0.649709 -0.415267
# 8  0.851084 -0.392048  ... -0.073425 -0.268092 -0.204233  1.011592  0.373205
# 9  0.069539 -0.736727  ... -0.246914 -0.633753 -0.120794 -0.385050 -0.069733
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
# 5  0.105915  0.253844  0.081080    3.67      0
# 6 -0.257237  0.034507  0.005168    4.99      0
# 7 -0.051634 -1.206921 -1.085339   40.80      0
# 8 -0.384157  0.011747  0.142404   93.20      0
# 9  0.094199  0.246219  0.083076    3.68      0
#
# [10 rows x 31 columns]

# %%
credit_card.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  3.919560e-15  5.688174e-16 -8.769071e-15  2.782312e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.552563e-15  2.010663e-15 -1.694249e-15 -1.927028e-16 -3.137024e-15
# std    1.380247e+00  1.332271e+00  1.237094e+00  1.194353e+00  1.098632e+00
# min   -1.137433e+02 -2.616051e+01 -4.355724e+01 -7.321672e+01 -1.343407e+01
# 25%   -6.915971e-01 -7.682956e-01 -5.540759e-01 -2.086297e-01 -6.430976e-01
# 50%   -5.433583e-02 -2.741871e-01  4.010308e-02  2.235804e-02 -5.142873e-02
# 75%    6.119264e-01  3.985649e-01  5.704361e-01  3.273459e-01  5.971390e-01
# max    3.480167e+01  7.330163e+01  1.205895e+02  2.000721e+01  1.559499e+01
#
#        ...           V21           V22           V23           V24  \
# count  ...  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   ...  1.537294e-16  7.959909e-16  5.367590e-16  4.458112e-15
# std    ...  7.345240e-01  7.257016e-01  6.244603e-01  6.056471e-01
# min    ... -3.483038e+01 -1.093314e+01 -4.480774e+01 -2.836627e+00
# 25%    ... -2.283949e-01 -5.423504e-01 -1.618463e-01 -3.545861e-01
# 50%    ... -2.945017e-02  6.781943e-03 -1.119293e-02  4.097606e-02
# 75%    ...  1.863772e-01  5.285536e-01  1.476421e-01  4.395266e-01
# max    ...  2.720284e+01  1.050309e+01  2.252841e+01  4.584549e+00
#
#                 V25           V26           V27           V28         Amount  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  284807.000000
# mean   1.453003e-15  1.699104e-15 -3.660161e-16 -1.206049e-16      88.349619
# std    5.212781e-01  4.822270e-01  4.036325e-01  3.300833e-01     250.120109
# min   -1.029540e+01 -2.604551e+00 -2.256568e+01 -1.543008e+01       0.000000
# 25%   -3.171451e-01 -3.269839e-01 -7.083953e-02 -5.295979e-02       5.600000
# 50%    1.659350e-02 -5.213911e-02  1.342146e-03  1.124383e-02      22.000000
# 75%    3.507156e-01  2.409522e-01  9.104512e-02  7.827995e-02      77.165000
# max    7.519589e+00  3.517346e+00  3.161220e+01  3.384781e+01   25691.160000
#
#                Class
# count  284807.000000
# mean        0.001727
# std         0.041527
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
#
# [8 rows x 31 columns]

# %%
print(f"Unique values of target variable :- \n {credit_card['Class'].unique()}")
# Out:
# Unique values of target variable :-
#  [0 1]

# %%
print(f"Number of samples under each target value :- \n {credit_card['Class'].value_counts()}")
# Out:
# Number of samples under each target value :-
#  0    284315
# 1       492
# Name: Class, dtype: int64

# %%
print(f"few values of Amount column :- \n {credit_card['Amount'][0:4]}")
# Out:
# few values of Amount column :-
#  0    149.62
# 1      2.69
# 2    378.66
# 3    123.50
# Name: Amount, dtype: float64

# %% [markdown]
# ## Data preprocessing

# %%
from sklearn.preprocessing import StandardScaler
credit_card['norm_amount'] = StandardScaler().fit_transform(
credit_card['Amount'].values.reshape(-1,1))
credit_card = credit_card.drop(['Amount'], axis=1)
print(f"few values of Amount column after applying StandardScaler:- \n {credit_card['norm_amount'][0:4]}")
# Out:
# few values of Amount column after applying StandardScaler:-
#  0    0.244964
# 1   -0.342475
# 2    1.160686
# 3    0.140534
# Name: norm_amount, dtype: float64

# %% [markdown]
# ## Target class distribution

# %%
class_val = credit_card['Class'].value_counts()
print(f"Number of samples for each class :- \n {class_val}")
# Out:
# Number of samples for each class :-
#  0    284315
# 1       492
# Name: Class, dtype: int64

# %% [markdown]
# ## Separating the data for analysis

# %%
legit = credit_card[credit_card.Class == 0]
fraud = credit_card[credit_card.Class == 1]

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (284315, 31)
# (492, 31)

# %% [markdown]
# ## Statistical measures of the data

# %%
legit_sample = legit.sample(n=5)

# %%
new_dataset = pd.concat([legit_sample, fraud], axis=0)

# %%
new_dataset.head()
# Out:
#               V1        V2        V3        V4        V5        V6        V7  \
# 228594 -1.270273  0.853395  0.523433 -0.672405  0.475017 -0.372917  0.780287
# 274262 -0.114367  0.387598 -0.377573 -0.024674  1.114740 -1.547832  0.903425
# 94368  -0.652377  1.356926  1.136196  0.870748  0.095873 -0.755019  0.751408
# 162190 -0.085090  1.075517 -1.013325 -0.307728  0.588308 -0.618826  0.406569
# 48929   0.851646 -1.022550  0.938416  0.152764 -1.067032  0.867689 -0.889042
#
#               V8        V9       V10  ...       V21       V22       V23  \
# 228594  0.522468 -1.035312 -0.670211  ... -0.167073 -0.809187  0.179049
# 274262 -0.466626  0.325434 -0.621630  ...  0.263228  0.957839 -0.048672
# 94368  -0.080338 -0.852188 -0.180519  ...  0.172270  0.613873 -0.171076
# 162190  0.299632  0.178591 -1.202024  ...  0.163514  0.532564  0.010829
# 48929   0.560370  1.225146 -0.368356  ... -0.077348 -0.292425  0.047792
#
#              V24       V25       V26       V27       V28  Class  norm_amount
# 228594 -0.328245 -0.225543  0.002884  0.142230  0.059525      0    -0.065792
# 274262 -0.120933 -0.437236 -0.185525 -0.169600 -0.041867      0    -0.317214
# 94368   0.442319 -0.130985 -0.362336 -0.246399 -0.135656      0    -0.302904
# 162190  0.558792 -0.663872  0.433840 -0.165536  0.054157      0    -0.345194
# 48929  -0.261204 -0.152353  0.978650 -0.039547  0.013594      0     0.152213
#
# [5 rows x 30 columns]

# %%
new_dataset.tail()
# Out:
#                V1         V2         V3        V4         V5        V6  \
# 279108  -1.322789   1.552768  -2.276921  2.992117  -1.947064 -0.480288
# 279194 -18.474868  11.586381 -21.402917  6.038515 -14.451158 -4.146524
# 279528   0.378275   3.914797  -5.726872  6.094141   1.698875 -2.807314
# 280854  -1.201398   4.864535  -8.328823  7.652399  -0.167445 -2.767695
# 282522  -6.677212   5.529299  -7.193275  6.081321  -1.636071  0.500610
#
#                V7         V8        V9       V10  ...       V21       V22  \
# 279108  -1.362388   0.953242 -2.329629 -3.393553  ...  0.614969 -0.195200
# 279194 -14.856124  12.431140 -4.053353 -9.040396  ...  1.741136 -1.251138
# 279528  -0.591118  -0.123496 -2.530713 -5.153095  ...  0.149896 -0.601967
# 280854  -3.176421   1.623279 -4.367228 -5.533443  ...  0.532320 -0.556913
# 282522  -4.640770  -4.339840 -0.950036  0.566680  ...  5.563301 -1.608272
#
#              V23       V24       V25       V26       V27       V28  Class  \
# 279108  0.590711 -0.233378 -0.164285 -0.277498  0.428610  0.246394      1
# 279194 -0.396219  0.095706  1.322751 -0.217955  1.628793  0.482248      1
# 279528 -0.613724 -0.403114  1.568445  0.521884  0.527938  0.411910      1
# 280854  0.192444 -0.698588  0.025003  0.514968  0.378105 -0.053133      1
# 282522  0.965322  0.163718  0.047531  0.466165  0.278547  1.471988      1
#
#         norm_amount
# 279108     0.726046
# 279194     0.046488
# 279528    -0.349191
# 280854    -0.350110
# 282522     0.070072
#
# [5 rows x 30 columns]

# %%
new_dataset['Class'].value_counts()
# Out:
# 0    25000
# 1      440
# Name: Class, dtype: int64

# %% [markdown]
# ## Features and target creations

# %%
x = new_dataset.drop(['Class'], axis=1)
y = new_dataset[['Class']]

# %% [markdown]
# ##  Splitting dataset to train & test dataset

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.25,random_state=0)
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (19080, 29)
# (6360, 29)
# (19080, 1)
# (6360, 1)

# %% [markdown]
# # RandomForestClassifier

# %%
rf_classifier = RandomForestClassifier()
# train model by using fit method
print("Model training start........")
rf_classifier.fit(X_train, y_train.values.ravel()) 
# predict result using test dataset

y_pred_1 = rf_classifier.predict(X_test)
print(f'Accuracy of model on test dataset :- {accuracy_score(y_test,y_pred_1)}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-4fa4ee0ed1db> in <module>
# ----> 1 rf_classifier = RandomForestClassifier()
#       2 # train model by using fit method
#       3 print("Model training start........")
#       4 rf_classifier.fit(X_train, y_train.values.ravel())
#       5 # predict result using test dataset
#
# NameError: name 'RandomForestClassifier' is not defined

# %% [markdown]
# # K-Nearest Neighbours

# %%
knn_classifier = KNeighborsClassifier()
# train model by using fit method
print("Model training start........")
knn_classifier.fit(X_train, y_train.values.ravel()) 
# predict result using test dataset
y_pred_2 = knn_classifier.predict(X_test)
print(f'Accuracy of model on test dataset :- {accuracy_score(y_test,y_pred_2)}')
# Out:
# Model training start........
# Accuracy of model on test dataset :- 0.9963836477987421

# %% [markdown]
# # Support Vector Machine

# %%
svc_classifier= SVC()
# train model by using fit method
print("Model training start........")
svc_classifier.fit(X_train, y_train.values.ravel()) 
# predict result using test dataset
y_pred_3 = svc_classifier.predict(X_test)
print(f'Accuracy of model on test dataset :- {accuracy_score(y_test,y_pred_3)}')
# Out:
# Model training start........
# Accuracy of model on test dataset :- 0.9955974842767296

# %% [markdown]
# # DecisionTreeClassifier

# %%
dt_classifier = DecisionTreeClassifier()
# train model by using fit method
print("Model training start........")
dt_classifier.fit(X_train, y_train.values.ravel()) 
# predict result using test dataset
y_pred_4 = dt_classifier.predict(X_test)
print(f'Accuracy of model on test dataset :- {accuracy_score(y_test,y_pred_4)}')
# Out:
# Model training start........
# Accuracy of model on test dataset :- 0.9933962264150943

# %% [markdown]
# ## Confusion matrix

# %%
cm1 = confusion_matrix(y_test, y_pred_1)
plt.figure(figsize = (8,5))
sns.heatmap(cm1, annot=True,fmt='d',cmap='OrRd_r')

# %% [markdown]
# ## Saving the Model

# %%
pickle.dump(rf_classifier, open('model1.pkl', 'wb'))

# %%
filename = "Model1.joblib"
joblib.dump(rf_classifier, filename)
# Out:
# ['Model1.joblib']
